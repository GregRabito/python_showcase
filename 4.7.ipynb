# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/rabito/Desktop/Rabito Docs/Documents/Career Foundry/Python/Instacart Basket Anaylsis'

# %%
df_ordss = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '4.5 Clean Orders Data.csv'))

# %% [markdown]
# # work

# %%
df_ordss.shape
# Out:
# (3421083, 9)

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data','Prepared Data', '4.6 orders_products_merge_final.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32434212, 15)

# %%
# Define Function

def add_num(x,y):
    sum = x+y
    return sum

# %%
# Taking the fitst million rows to avoid meemory issues. 
# The colon indicates that everything should be taken from the begining
# of the term to the indicated number. With no number it starts with the beginning to 1 million.

df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# # price_label ranges

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/gc/00zck94n7xg4v6fr7ggfw0km0000gp/T/ipykernel_98662/3677927974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    659373
# Low-range product    331283
# High range             9344
# Name: count, dtype: int64

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts (dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts (dropna = False)
# Out:
# busiest_day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %%
result_2 = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Slowest days")
  else:
    result_2.append("Regularly busy")

# %%
result_2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
df_ords_prods_merge['busiest_days'] = result_2

# %%
df_ords_prods_merge['busiest_days'].value_counts (dropna = False)
# Out:
# busiest_days
# Regularly busy    12927461
# Busiest days      11875462
# Slowest days       7631289
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head
# Out:
# <bound method NDFrame.head of           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32434207       49688      Fresh Foaming Cleanser        73             11
# 32434208       49688      Fresh Foaming Cleanser        73             11
# 32434209       49688      Fresh Foaming Cleanser        73             11
# 32434210       49688      Fresh Foaming Cleanser        73             11
# 32434211       49688      Fresh Foaming Cleanser        73             11
#
# ...

# %%
df_ords_prods_merge['order_hour_of_day'].value_counts (dropna = False)
# Out:
# order_hour_of_day
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: count, dtype: int64

# %%
result_3 = []

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value in [9,10,11,12,13,14,15,16]:
    result_3.append("Most orders")
  elif value in [0,1,2,3,4,5,6,7,20,21,22,23]:
    result_3.append("Fewest orders")
  else:
    result_3.append("Regular hours")

# %%
result_3
# Out:
# ['Most orders',
#  'Regular hours',
#  'Fewest orders',
#  'Most orders',
#  'Regular hours',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Regular hours',
#  'Regular hours',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Regular hours',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Regular hours',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Regular hours',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Regular hours',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
df_ords_prods_merge['busiest_period_of_day'] =result_3

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts (dropna = False)
# Out:
# busiest_period_of_day
# Most orders      21137262
# Regular hours     6706708
# Fewest orders     4590242
# Name: count, dtype: int64

# %% [markdown]
# # export

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, 'Data','Prepared Data', '4.7 orders_products_merge_final.pkl'))
